# %% [markdown]
# Import libraries

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# Read revenue data

# %%
directory_output = '../data/output/'
revenue_predictions = pd.read_csv(directory_output+'5 predictions.csv')

# %% [markdown]
# Plot historical and predicted revenue as a function of time

# %%
revenue_predictions[['revenue','forecast_arima', 'forecast_sarima']].plot()
plt.draw()
